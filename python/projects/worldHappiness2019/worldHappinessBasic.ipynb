# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# !ls
# Out:
# info.txt
# worldHappinessBasic.ipynb
# world-happiness-report-2019.csv

# %%
df=pd.read_csv("world-happiness-report-2019.csv")
df
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# 5                 Switzerland       6            11             44.0
# 6                      Sweden       7            18             34.0
# 7                 New Zealand       8            15             22.0
# 8                      Canada       9            23             18.0
# 9                     Austria      10            10             64.0
# 10                  Australia      11            26             47.0
# 11                 Costa Rica      12            62              4.0
# 12                     Israel      13            14            104.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
# Country (region)           156 non-null object
# Ladder                     156 non-null int64
# SD of Ladder               156 non-null int64
# Positive affect            155 non-null float64
# Negative affect            155 non-null float64
# Social support             155 non-null float64
# Freedom                    155 non-null float64
# Corruption                 148 non-null float64
# Generosity                 155 non-null float64
# Log of GDP
# per capita      152 non-null float64
# Healthy life
# expectancy    150 non-null float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.5+ KB

# %%
df.corr()
# Out:
#                             Ladder  SD of Ladder  Positive affect  \
# Ladder                    1.000000      0.539362         0.491432
# SD of Ladder              0.539362      1.000000         0.085381
# Positive affect           0.491432      0.085381         1.000000
# Negative affect           0.523643      0.619267         0.389697
# Social support            0.817842      0.599464         0.386269
# Freedom                   0.546777      0.251856         0.681770
# Corruption                0.190071      0.258639         0.209659
# Generosity                0.497856      0.392154         0.354877
# Log of GDP\nper capita    0.813367      0.629662         0.304522
# Healthy life\nexpectancy  0.816740      0.611376         0.332839
#
#                           Negative affect  Social support   Freedom  \
# Ladder                           0.523643        0.817842  0.546777
# SD of Ladder                     0.619267        0.599464  0.251856
# ...

# %%
plt.figure(dpi=120)
sns.heatmap(df.corr())

# %%
df.corr()["Ladder"]
# Out:
# Ladder                      1.000000
# SD of Ladder                0.539362
# Positive affect             0.491432
# Negative affect             0.523643
# Social support              0.817842
# Freedom                     0.546777
# Corruption                  0.190071
# Generosity                  0.497856
# Log of GDP\nper capita      0.813367
# Healthy life\nexpectancy    0.816740
# Name: Ladder, dtype: float64

# %%
df.corr()["Ladder"][1:]
# Out:
# SD of Ladder                0.539362
# Positive affect             0.491432
# Negative affect             0.523643
# Social support              0.817842
# Freedom                     0.546777
# Corruption                  0.190071
# Generosity                  0.497856
# Log of GDP\nper capita      0.813367
# Healthy life\nexpectancy    0.816740
# Name: Ladder, dtype: float64

# %%
df.corr()["Ladder"][1:].sort_values()
# Out:
# Corruption                  0.190071
# Positive affect             0.491432
# Generosity                  0.497856
# Negative affect             0.523643
# SD of Ladder                0.539362
# Freedom                     0.546777
# Log of GDP\nper capita      0.813367
# Healthy life\nexpectancy    0.816740
# Social support              0.817842
# Name: Ladder, dtype: float64

# %%
df.corr()["Ladder"][1:].sort_values(ascending=False)
# Out:
# Social support              0.817842
# Healthy life\nexpectancy    0.816740
# Log of GDP\nper capita      0.813367
# Freedom                     0.546777
# SD of Ladder                0.539362
# Negative affect             0.523643
# Generosity                  0.497856
# Positive affect             0.491432
# Corruption                  0.190071
# Name: Ladder, dtype: float64

# %%
df.mean()
# Out:
# Ladder                      78.5
# SD of Ladder                78.5
# Positive affect             78.0
# Negative affect             78.0
# Social support              78.0
# Freedom                     78.0
# Corruption                  74.5
# Generosity                  78.0
# Log of GDP\nper capita      76.5
# Healthy life\nexpectancy    75.5
# dtype: float64

# %%
df[df["Country (region)"]=="India"]
# Out:
#     Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 139            India     140            41             93.0            115.0
#
#      Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 139           142.0     41.0        73.0        65.0                   103.0
#
#      Healthy life\nexpectancy
# 139                     105.0

# %%
df.iloc[:5,:]
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
top5=df.iloc[:5,:].mean()
top5
# Out:
# Ladder                       3.0
# SD of Ladder                 7.0
# Positive affect             19.2
# Negative affect             18.6
# Social support               5.0
# Freedom                      8.0
# Corruption                  14.4
# Generosity                  18.0
# Log of GDP\nper capita      14.0
# Healthy life\nexpectancy    18.6
# dtype: float64

# %%
india=df[df["Country (region)"]=="India"].squeeze()[1:]
india
# Out:
# Ladder                      140
# SD of Ladder                 41
# Positive affect              93
# Negative affect             115
# Social support              142
# Freedom                      41
# Corruption                   73
# Generosity                   65
# Log of GDP\nper capita      103
# Healthy life\nexpectancy    105
# Name: 139, dtype: object

# %%
df1=pd.DataFrame({"top5":top5,"India":india})
df1
# Out:
#                           top5 India
# Ladder                     3.0   140
# SD of Ladder               7.0    41
# Positive affect           19.2    93
# Negative affect           18.6   115
# Social support             5.0   142
# Freedom                    8.0    41
# Corruption                14.4    73
# Generosity                18.0    65
# Log of GDP\nper capita    14.0   103
# Healthy life\nexpectancy  18.6   105

# %%
df1["Difference"]=df1["top5"]-df1["India"]
df1
# Out:
#                           top5 India Difference
# Ladder                     3.0   140       -137
# SD of Ladder               7.0    41        -34
# Positive affect           19.2    93      -73.8
# Negative affect           18.6   115      -96.4
# Social support             5.0   142       -137
# Freedom                    8.0    41        -33
# Corruption                14.4    73      -58.6
# Generosity                18.0    65        -47
# Log of GDP\nper capita    14.0   103        -89
# Healthy life\nexpectancy  18.6   105      -86.4
